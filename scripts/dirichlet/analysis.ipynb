# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
with open('phi4-dirichlet-scan.npy', 'rb') as file:
        mosaic = np.load(file)

plt.figure(figsize=(10, 7))
plt.imshow(mosaic, origin='lower', aspect='auto', cmap='seismic', interpolation='none', extent=(-1, 2, 0, 1))
# plt.ylabel(r'$v$')
# plt.xlabel(r'$\lambda$')
# plt.title('kink-antikink')
plt.tight_layout()
plt.show()

# %%
np.arange(9).reshape()[*(i for i in [0, 1])]
# Out:
# numpy.ndarray[float]
